# %%
import pandas as pd

# %%
df=pd.read_csv("WineQT.csv")
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# 2      9.8        5   2
# 3      9.8        6   3
# 4      9.4        5   4

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# Id                      0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop(columns=['alcohol'])
y = df['alcohol']

# %%
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=0.3,random_state=42)

# %%
X_train.shape
# Out:
# (800, 12)

# %%
X_test.shape
# Out:
# (343, 12)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)
y_pred
# Out:
# array([10.35821571, 10.40209881, 10.12343653,  9.64508782, 10.69764055,
#        13.1218675 ,  9.80637506,  9.67249061, 10.19073196,  9.64110541,
#        11.46364189, 11.4582724 , 10.5909125 , 11.76881309, 11.61201984,
#        10.26363305,  9.99840064, 10.03750802,  9.96581533, 11.04387417,
#        10.43773521, 10.87520512, 10.05145089, 11.40027937,  9.94066403,
#         9.6492416 , 12.40555323, 10.37629236,  9.93083472, 10.63435825,
#        12.73185393,  9.72023309, 11.79199928, 10.00182674, 10.00036519,
#         9.59927704,  9.19329199, 11.0426568 , 13.26491938,  9.18558674,
#        11.25778339, 10.11359702, 12.76082246,  9.70629891,  9.27822942,
#         9.80133797, 10.92503857,  9.72204813,  9.89105133, 10.83443989,
#        12.01133406, 10.40192194, 10.34360123, 10.77216182, 10.41594721,
#        11.4060776 , 10.21920025, 10.05794509, 10.68878752, 10.14683165,
#         8.63951067, 11.14846189, 10.37649736, 11.54645834, 11.38935204,
#        10.4101246 , 11.47250332,  9.84118785, 10.17426201, 10.14520191,
#         9.70809353,  9.34914612,  9.84878459, 11.79121495, 10.64381523,
#         9.37680714, 10.01654052,  9.79124519, 10.13758858,  9.7126861 ,
#        10.19896875, 10.75556537, 10.61335312, 10.14744085,  9.93203021,
#        10.67662409, 11.95340575,  9.98955738, 11.85646096, 10.00331665,
#        11.14440809, 10.14366023, 10.11991773,  9.47406853,  9.35165875,
#         9.75682357, 10.13866084, 11.04620054,  9.54294414,  9.93423687,
#        11.36058919, 13.15641265,  9.27972871, 10.52078738, 10.65241388,
#         9.88577237, 10.29481359, 10.17001881, 10.60662148, 10.75301334,
#        10.47173119,  9.00443266,  9.57019903, 10.61087129,  9.31463172,
#         8.86552918,  9.50162032, 12.09911723, 11.05324662,  9.90627236,
#         9.6692147 ,  9.93129505, 10.53739158,  9.95087391, 10.15142921,
#        10.51258353,  9.62590804, 11.31765571, 10.38798264, 10.32417452,
#         9.70232187,  9.38884201, 12.93098177, 10.13628596, 13.95722033,
#        11.18166599,  9.73816478, 10.20016065, 10.73932625, 10.85334804,
#        12.49013543,  9.59259976,  9.97436471,  9.93390922, 10.88350816,
#         9.63432188,  8.75530676,  9.78481668,  9.9469419 ,  9.83514075,
#        11.21267364,  9.67987113, 10.8501153 ,  8.17396402,  9.56144424,
#        10.10262271,  9.7849416 ,  9.52598516, 11.78771764, 10.94964166,
#        10.54805535,  9.67983715, 10.9107072 , 10.63291264, 11.3118908 ,
#         9.98865779, 10.67718396, 10.80342656, 10.20857951,  8.72060018,
#        12.1408732 , 10.11576456,  9.369271  ,  9.79461333,  9.63839532,
#         9.46204989, 11.80896221,  9.70276618,  9.58758753, 10.48399995,
#        10.74108027, 10.43499264,  9.50766482, 10.38599057,  9.40934216,
#         9.27013251, 11.51223751,  9.41671462, 10.96377123, 10.87530833,
#        10.86164166,  9.89619717, 12.00997247, 10.37305781, 10.20856569,
#        10.1449289 ,  9.49491479, 11.73009298, 11.96251715, 10.88597662,
#        11.40917333, 10.5208361 ,  9.72322014,  9.99693103, 10.91641191,
#        10.2676529 ,  9.42422704,  9.34351316, 11.60344457, 10.46891104,
#        10.63569529, 10.30675923,  9.98644078, 10.63514131,  9.49696522,
#         9.92927058, 10.8333827 , 10.05133975, 11.47636621,  9.97945547,
#        11.65237246, 10.13404184,  9.89545694, 10.2711829 , 11.22686369,
#        10.08577453, 10.091316  , 10.26945894, 10.93808876, 10.45034051,
#        11.68895049, 11.60078842, 10.47929187,  8.84404543, 11.98670121,
#        12.60453224,  9.90387338, 11.92807608,  9.82368309,  8.84090839,
#        11.60715691, 10.51959396, 10.75159698, 10.17203002, 12.19999139,
#        10.3058511 ,  9.74943366, 10.35609528, 10.79934339,  9.87899796,
#        10.07654796,  9.97236281, 13.41645673, 12.39170743,  9.40082545,
#        11.93780838, 11.26369531, 10.24723576,  9.4803062 ,  9.56183476,
#        10.51270845, 10.14442924, 11.7988694 ,  9.49367001,  9.20462988,
#         9.93216904, 10.64050576, 11.2843446 ,  9.43171686, 10.83557934,
#         9.51877546, 12.55673784,  9.36449087, 11.44330447, 10.08202796,
#        10.20882753, 10.01898112, 12.39208217,  9.83433596, 10.53001892,
#         9.70436622, 12.06299904, 10.12799913,  9.31491892, 10.48263217,
#        12.20489901,  9.77745463,  9.7742534 , 10.41299184, 10.39480731,
#        10.54287657,  9.91627654, 11.67186496, 10.53321257, 11.13620809,
#        10.58176734, 11.54117034, 10.06833629, 10.74596272, 10.10708063,
#         9.71629464, 10.08843486, 10.43335506, 10.11796154,  9.30106124,
#        10.37514045, 12.94093565, 10.87575012, 11.37508015, 10.14172503,
#         9.78553623, 11.75791167, 11.67926141,  9.0503439 , 10.49177443,
#         9.48941653, 10.34139987, 10.32589376, 11.42915255,  9.30158394,
#         8.8859833 , 10.01679035,  9.76182505,  9.27860582, 10.80684337,
#        11.96095089, 12.78614971,  9.83785944,  9.71958665, 10.01226879,
#        12.13514743,  9.9887827 ,  9.82824493, 12.43859426,  9.73068162,
#         9.52947378, 11.44063902, 10.4234722 , 10.46618044, 10.49701347,
#        10.60660934,  9.30926584,  9.78895721])

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
mae= mean_absolute_error(y_test,y_pred)
mse= mean_squared_error(y_test,y_pred)

mae,mse
# Out:
# (0.46131448028226607, 0.3658809005626739)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
model2=DecisionTreeRegressor(max_depth=4,random_state=42)
model2.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=4, random_state=42)

# %%
y_pred=model.predict(X_test)

# %%
mae=mean_absolute_error(y_test,y_pred)
mae
# Out:
# 0.46131448028226607

# %%
mse=mean_squared_error(y_test,y_pred)
mse
# Out:
# 0.3658809005626739

# %%
from sklearn.tree import plot_tree

plt.figure(figsize=(20,10))
plot_tree(model2,feature_names=X.columns,filled =True,rounded=True)
plt.title("Decision Tree")
# Out:
# Text(0.5, 1.0, 'Decision Tree')
